# %% [markdown]
# ### Reading the datafile for drug discovery with the help of read_csv file of Pandas library

# %%
import pandas as pd

df = pd.read_csv("refined_data_heatmap.csv")

df.head()
# Out:
#    Unnamed: 0  activity_comment  activity_id activity_properties  \
# 0           0                -1        33969                  []
# 1           1                -1        37563                  []
# 2           2                -1        37565                  []
# 3           3                -1        38902                  []
# 4           4                -1        41170                  []
#
#    assay_chembl_id  assay_description  assay_type  bao_endpoint  bao_format  \
# 0              546                581           1             1           4
# 1              546                581           1             1           4
# 2              546                581           1             1           4
# 3              546                581           1             1           4
# 4              546                581           1             1           4
#
#    bao_label  ...  src_id  standard_flag  standard_relation  standard_units  \
# 0          3  ...       1              1                  1               4
# 1          3  ...       1              1                  1               4
# 2          3  ...       1              1                  2               4
# 3          3  ...       1              1                  1               4
# 4          3  ...       1              1                  1               4
#
#    standard_value  type units  uo_units  upper_value  value
# 0            2508     1    23         0           -1    429
# 1             151     1    23         0           -1    253
# 2            1985     1    23         0           -1   2061
# 3            1370     1    23         0           -1    326
# 4            2618     1    23         0           -1    442
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Exploratory Data Analysis using Heatmap of cross-correlation matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.gcf().set_size_inches(15, 15)

cmap=sns.diverging_palette(500,10,as_cmap=True)

sns.heatmap(df.corr(),cmap=cmap,center=0,annot=False,square=True)

plt.show()
# Out:
# Matplotlib created a temporary config/cache directory at /var/folders/w1/ddjn79r10gb30q27xq0t_fjw0000gn/T/matplotlib-g62jz5to because the default path (/Users/ravishkumar/.matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# /var/folders/w1/ddjn79r10gb30q27xq0t_fjw0000gn/T/ipykernel_54754/348324069.py:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cmap=cmap,center=0,annot=False,square=True)

# %% [markdown]
# ### Fetching newer data and then again plotting the heatmap

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

data = new_client.target
data_new = new_client.activity

data1 = data_new.filter(target_chembl_id='CHEMBL220').filter(standard_type="IC50")

df = pd.DataFrame.from_dict(data1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.gcf().set_size_inches(15, 15)

cmap=sns.diverging_palette(500,10,as_cmap=True)

sns.heatmap(df.corr(),cmap=cmap,center=0,annot=False,square=True)
# Out:
# /var/folders/w1/ddjn79r10gb30q27xq0t_fjw0000gn/T/ipykernel_54754/2575284273.py:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cmap=cmap,center=0,annot=False,square=True)
# <AxesSubplot: >

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

data = new_client.target
data_query = data.search('acetylcholinesterase')

targets = pd.DataFrame.from_dict(data_query)

# %%
targets.keys()
# Out:
# Index(['cross_references', 'organism', 'pref_name', 'score',
#        'species_group_flag', 'target_chembl_id', 'target_components',
#        'target_type', 'tax_id'],
#       dtype='object')
